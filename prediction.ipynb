# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Gold.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 676 entries, 0 to 675
# Data columns (total 21 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Date                                    676 non-null    object
#  1   Price 2 Days Prior                      676 non-null    float64
#  2   Price 1 Day Prior                       676 non-null    float64
#  3   Price Today                             676 non-null    float64
#  4   Price Tomorrow                          675 non-null    float64
#  5   Price Change Tomorrow                   675 non-null    float64
#  6   Price Change Ten                        666 non-null    float64
#  7   Std Dev 10                              667 non-null    float64
#  8   Twenty Moving Average                   676 non-null    float64
#  9   Fifty Day Moving Average                676 non-null    float64
# ...

# %%
df.describe()
# Out:
#        Price 2 Days Prior  Price 1 Day Prior  Price Today  Price Tomorrow  \
# count          676.000000         676.000000   676.000000      675.000000
# mean          1956.236228        1957.114305  1957.937944     1958.165600
# std            192.959980         193.560530   194.198338      194.252056
# min           1627.040000        1627.040000  1627.040000     1627.040000
# 25%           1823.587500        1824.490000  1824.490000     1824.880000
# 50%           1930.910000        1931.405000  1931.515000     1931.590000
# 75%           2021.452500        2022.290000  2023.977500     2024.075000
# max           2469.650000        2469.650000  2469.650000     2469.650000
#
#        Price Change Tomorrow  Price Change Ten  Std Dev 10  \
# count             675.000000        666.000000  667.000000
# mean                0.861570          8.944414   20.995813
# std                17.531773         55.681937   10.470747
# min               -81.890000       -124.290000    5.587177
# ...

# %%
df.head()
# Out:
#      Date  Price 2 Days Prior  Price 1 Day Prior  Price Today  Price Tomorrow  \
# 0  8/7/24             2405.87            2384.90      2385.83             NaN
# 1  8/6/24             2442.74            2405.87      2384.90         2385.83
# 2  8/5/24             2447.17            2442.74      2405.87         2384.90
# 3  8/2/24             2447.23            2447.17      2442.74         2405.87
# 4  8/1/24             2411.09            2447.23      2447.17         2442.74
#
#    Price Change Tomorrow  Price Change Ten  Std Dev 10  Twenty Moving Average  \
# 0                    NaN               NaN   30.155078              2414.7450
# 1                   0.93               NaN   29.423936              2414.1525
# 2                 -20.97               NaN   28.341301              2413.2305
# 3                 -36.87               NaN   28.616661              2411.0920
# 4                  -4.43               NaN   26.084796              2408.5670
#
# ...

# %%
x_new = df.drop("Date",axis=1)

# %%
cor_rel = x_new.corr()

# %%
x_new.columns
# Out:
# Index(['Price 2 Days Prior', 'Price 1 Day Prior', 'Price Today',
#        'Price Tomorrow', 'Price Change Tomorrow', 'Price Change Ten',
#        'Std Dev 10', 'Twenty Moving Average', 'Fifty Day Moving Average',
#        '200 Day Moving Average', 'Monthly Inflation Rate', 'EFFR Rate',
#        'Volume ', 'Treasury Par Yield Month', 'Treasury Par Yield Two Year',
#        'Treasury Par Yield Curve Rates (10 Yr)', 'DXY', 'SP Open', 'VIX',
#        'Crude'],
#       dtype='object')

# %%
x_new.head()
# Out:
#    Price 2 Days Prior  Price 1 Day Prior  Price Today  Price Tomorrow  \
# 0             2405.87            2384.90      2385.83             NaN
# 1             2442.74            2405.87      2384.90         2385.83
# 2             2447.17            2442.74      2405.87         2384.90
# 3             2447.23            2447.17      2442.74         2405.87
# 4             2411.09            2447.23      2447.17         2442.74
#
#    Price Change Tomorrow  Price Change Ten  Std Dev 10  Twenty Moving Average  \
# 0                    NaN               NaN   30.155078              2414.7450
# 1                   0.93               NaN   29.423936              2414.1525
# 2                 -20.97               NaN   28.341301              2413.2305
# 3                 -36.87               NaN   28.616661              2411.0920
# 4                  -4.43               NaN   26.084796              2408.5670
#
# ...

# %%
target = x_new["Price Today"]

# %%
cor_rel["Price Today"]
# Out:
# Price 2 Days Prior                        0.992064
# Price 1 Day Prior                         0.995910
# Price Today                               1.000000
# Price Tomorrow                            0.995919
# Price Change Tomorrow                    -0.010368
# Price Change Ten                         -0.017170
# Std Dev 10                                0.259093
# Twenty Moving Average                     0.749467
# Fifty Day Moving Average                  0.589052
# 200 Day Moving Average                    0.406959
# Monthly Inflation Rate                   -0.680608
# EFFR Rate                                 0.538895
# Volume                                   -0.174374
# Treasury Par Yield Month                  0.503755
# Treasury Par Yield Two Year               0.339683
# Treasury Par Yield Curve Rates (10 Yr)    0.443558
# DXY                                      -0.171748
# SP Open                                   0.880275
# ...

# %%
X = x_new[["Price 2 Days Prior","Price 1 Day Prior","Price Tomorrow"]]
X2 = x_new[["Price 2 Days Prior","Price 1 Day Prior","Price Tomorrow","SP Open"]]

# %%
X.head()
# Out:
#    Price 2 Days Prior  Price 1 Day Prior  Price Tomorrow
# 0             2405.87            2384.90             NaN
# 1             2442.74            2405.87         2385.83
# 2             2447.17            2442.74         2384.90
# 3             2447.23            2447.17         2405.87
# 4             2411.09            2447.23         2442.74

# %%
target.head()
# Out:
# 0    2385.83
# 1    2384.90
# 2    2405.87
# 3    2442.74
# 4    2447.17
# Name: Price Today, dtype: float64

# %%
print(X["Price Tomorrow"].isna().sum())
print(X["Price 1 Day Prior"].isna().sum())
print(X["Price 2 Days Prior"].isna().sum())
# Out:
# 1
# 0
# 0

# %%
median = X["Price Tomorrow"].median()
median
# Out:
# 1931.59

# %%
X.head()
# Out:
#    Price 2 Days Prior  Price 1 Day Prior  Price Tomorrow
# 0             2405.87            2384.90             NaN
# 1             2442.74            2405.87         2385.83
# 2             2447.17            2442.74         2384.90
# 3             2447.23            2447.17         2405.87
# 4             2411.09            2447.23         2442.74

# %%
type(target)
# Out:
# pandas.core.series.Series

# %%
X.head()
# Out:
#    Price 2 Days Prior  Price 1 Day Prior  Price Tomorrow
# 0             2405.87            2384.90             NaN
# 1             2442.74            2405.87         2385.83
# 2             2447.17            2442.74         2384.90
# 3             2447.23            2447.17         2405.87
# 4             2411.09            2447.23         2442.74

# %%
X["Price Tomorrow"].fillna(median,inplace=True)
# Out:
# C:\Users\Pratik\AppData\Local\Temp\ipykernel_2352\1750113094.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X["Price Tomorrow"].fillna(median,inplace=True)
# C:\Users\Pratik\AppData\Local\Temp\ipykernel_2352\1750113094.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X["Price Tomorrow"].fillna(median,inplace=True)

# %%
X.head()
# Out:
#    Price 2 Days Prior  Price 1 Day Prior  Price Tomorrow
# 0             2405.87            2384.90         1931.59
# 1             2442.74            2405.87         2385.83
# 2             2447.17            2442.74         2384.90
# 3             2447.23            2447.17         2405.87
# 4             2411.09            2447.23         2442.74

# %%
type(X)
# Out:
# pandas.core.frame.DataFrame

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 676 entries, 0 to 675
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Price 2 Days Prior  676 non-null    float64
#  1   Price 1 Day Prior   676 non-null    float64
#  2   Price Tomorrow      676 non-null    float64
# dtypes: float64(3)
# memory usage: 16.0 KB

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
type(target)
# Out:
# pandas.core.series.Series

# %%
y = target

# %%
len(X)
# Out:
# 676

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 676 entries, 0 to 675
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Price 2 Days Prior  676 non-null    float64
#  1   Price 1 Day Prior   676 non-null    float64
#  2   Price Tomorrow      676 non-null    float64
# dtypes: float64(3)
# memory usage: 16.0 KB

# %%
x_train = X[:600]
x_test = X[600:]

# %%
y_train = y[:600]
y_test = y[600:]

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
pred = model.predict(x_test)

# %%
from sklearn.metrics import root_mean_squared_error
error = root_mean_squared_error(pred,y_test)

# %%
error
# Out:
# 13.186775701730038

# %%
X2_train = X2[:600]
X2_test = X2[600:]

# %%
from sklearn.linear_model import LinearRegression
model1 = LinearRegression()

# %%
median
# Out:
# 1931.59

# %%
X2.head()
# Out:
#    Price 2 Days Prior  Price 1 Day Prior  Price Tomorrow  SP Open
# 0             2405.87            2384.90             NaN  5293.13
# 1             2442.74            2405.87         2385.83  5206.42
# 2             2447.17            2442.74         2384.90  5151.14
# 3             2447.23            2447.17         2405.87  5376.63
# 4             2411.09            2447.23         2442.74  5537.84

# %%
X2["Price Tomorrow"].fillna(median,inplace=True)
# Out:
# C:\Users\Pratik\AppData\Local\Temp\ipykernel_2352\4067099908.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X2["Price Tomorrow"].fillna(median,inplace=True)
# C:\Users\Pratik\AppData\Local\Temp\ipykernel_2352\4067099908.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X2["Price Tomorrow"].fillna(median,inplace=True)

# %%
model1.fit(X2_train,y_train)
# Out:
# LinearRegression()

# %%
pred2 = model1.predict(X2_test)

# %%
error2 = root_mean_squared_error(pred2,y_test)

# %%
error2
# Out:
# 13.220235886914567
